# %%
from pyglossary import Glossary

g = Glossary()
g.open(r"C:\Users\Admin\Desktop\ooal\language_learn\dictionaries\eng-deu\eng-deu")

print(g.lookup_word("house"))
print(g.lookup_word("world"))
print(g.lookup_word("apple"))
